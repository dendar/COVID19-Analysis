# %% [markdown]
# # COVID-19 Pandemic by the Numbers
#
# by Nadir Sarigul
#
# See (link for blog) for description

# %% [markdown]
# # Data Preparation
#
# The data used in this analysis can be found at https://datacatalog.worldbank.org/

# %%
# import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
import numpy as np 
import plotly.offline as  pyo
import plotly.graph_objs as go

obesity = pd.read_csv("obesity.csv")
diabetes = pd.read_csv("diabetes.csv")
gdp = pd.read_excel(r"Income_world_bank.xls")

populations = pd.read_csv("Populations.csv")
years = pd.read_excel(r"65_year_above.xls", header= 1)
covid = pd.read_excel(r"COVID19 data.xlsx")

import warnings 
warnings.filterwarnings('ignore')

# %%
# drop features that we dont need on the gdp dataset
gdp = gdp.drop(["Region","country"], axis= 1)
# merge gdp and diabetes dataset
df = gdp.merge(diabetes,  how='inner', on='Country Code' )

# %%
df
# Out:
#     Country Code          IncomeGroup  Country Name  % Diabetes
# 0            ABW          High income         Aruba        11.6
# 1            AFG           Low income   Afghanistan         9.2
# 2            AGO  Lower middle income        Angola         4.5
# 3            ALB  Upper middle income       Albania         9.0
# 4            AND          High income       Andorra         7.7
# ..           ...                  ...           ...         ...
# 258          XKX  Upper middle income        Kosovo         NaN
# 259          YEM           Low income   Yemen, Rep.         5.4
# 260          ZAF  Upper middle income  South Africa        12.7
# 261          ZMB  Lower middle income        Zambia         4.5
# 262          ZWE  Lower middle income      Zimbabwe         1.8
#
# [263 rows x 4 columns]

# %%
# get features we needs from populations dataset
populations =populations[["name","pop2021"]]
populations = populations.rename({"name":"Country Name"}, axis = 1)

# %%
# merge df and populations dataset
df = df.merge(populations,  how='inner', on='Country Name' )

# %%
df["IncomeGroup"].value_counts()
# Out:
# High income            71
# Upper middle income    49
# Lower middle income    41
# Low income             24
# Name: IncomeGroup, dtype: int64

# %%
# drop Country Name feature from years dataset
years = years.drop("Country Name", axis =1)

# %%
# merge years with df
df = df.merge(years,  how='inner', on='Country Code' )

# %%
df
# Out:
#     Country Code          IncomeGroup  Country Name  % Diabetes    pop2021  \
# 0            ABW          High income         Aruba        11.6    107.204
# 1            AFG           Low income   Afghanistan         9.2  39835.428
# 2            AGO  Lower middle income        Angola         4.5  33933.610
# 3            ALB  Upper middle income       Albania         9.0   2872.933
# 4            AND          High income       Andorra         7.7     77.355
# ..           ...                  ...           ...         ...        ...
# 180          VUT  Lower middle income       Vanuatu        11.9    314.464
# 181          WSM  Upper middle income         Samoa         9.2    200.149
# 182          ZAF  Upper middle income  South Africa        12.7  60041.994
# 183          ZMB  Lower middle income        Zambia         4.5  18920.651
# 184          ZWE  Lower middle income      Zimbabwe         1.8  15092.171
#
#      % pop > 65 years
# 0           14.058355
# 1            2.615794
# 2            2.199342
# 3           14.202631
# 4                 NaN
# ..                ...
# 180          3.616089
# 181          4.933104
# 182          5.415256
# 183          2.115315
# 184          2.980608
#
# [185 rows x 6 columns]

# %%
#Drop pop2021 feature from obesity
obesity =obesity.drop("pop2021", axis =1)
# change country column name to Country Name
obesity = obesity.rename({'country': 'Country Name'}, axis=1)

# %%
#merge obesity to df dataset
df = df.merge(obesity,  how='inner', on='Country Name' )

# %%
# drop features we dont need 
covid = covid.drop(["continent","date"], axis=1)
# rename location column to Country Name
covid = covid.rename({"location":"Country Name" }, axis =1)
covid
# Out:
#     Country Name  total_cases  total_deaths  total_cases_per_million  \
# 0    Afghanistan      58312.0        2561.0                 1497.932
# 1         Africa    4474950.0      119227.0                 3338.025
# 2        Albania     130114.0        2364.0                45213.010
# 3        Algeria     120363.0        3181.0                 2744.815
# 4        Andorra      12942.0         123.0               167501.456
# ..           ...          ...           ...                      ...
# 202      Vietnam       2824.0          35.0                   29.012
# 203        World  144742651.0     3071857.0                18569.133
# 204        Yemen       6020.0        1157.0                  201.838
# 205       Zambia      91189.0        1240.0                 4960.249
# 206     Zimbabwe      38018.0        1555.0                 2557.908
#
#      total_deaths_per_million
# 0                      65.788
# 1                      88.936
# 2                     821.461
# 3                      72.541
# 4                    1591.924
# ..                        ...
# 202                     0.360
# 203                   394.091
# 204                    38.792
# 205                    67.450
# 206                   104.623
#
# [207 rows x 5 columns]

# %%
# merge covid data with df
df = df.merge(covid,how='inner', on='Country Name')
df
# Out:
#     Country Code          IncomeGroup          Country Name  % Diabetes  \
# 0            AFG           Low income           Afghanistan         9.2
# 1            AGO  Lower middle income                Angola         4.5
# 2            ALB  Upper middle income               Albania         9.0
# 3            AND          High income               Andorra         7.7
# 4            ARE          High income  United Arab Emirates        16.3
# ..           ...                  ...                   ...         ...
# 153          VUT  Lower middle income               Vanuatu        11.9
# 154          WSM  Upper middle income                 Samoa         9.2
# 155          ZAF  Upper middle income          South Africa        12.7
# 156          ZMB  Lower middle income                Zambia         4.5
# 157          ZWE  Lower middle income              Zimbabwe         1.8
#
#        pop2021  % pop > 65 years  obesityRate  total_cases  total_deaths  \
# 0    39835.428          2.615794          5.5      58312.0        2561.0
# 1    33933.610          2.199342          8.2      25051.0         572.0
# 2     2872.933         14.202631         21.7     130114.0        2364.0
# 3       77.355               NaN         25.6      12942.0         123.0
# 4     9991.089          1.156549         31.7     504872.0        1565.0
# ..         ...               ...          ...          ...           ...
# 153    314.464          3.616089         25.2          4.0           1.0
# 154    200.149          4.933104         47.3          3.0           NaN
# 155  60041.994          5.415256         28.3    1571348.0       53995.0
# 156  18920.651          2.115315          8.1      91189.0        1240.0
# 157  15092.171          2.980608         15.5      38018.0        1555.0
#
#      total_cases_per_million  total_deaths_per_million
# 0                   1497.932                    65.788
# 1                    762.210                    17.404
# 2                  45213.010                   821.461
# 3                 167501.456                  1591.924
# 4                  51046.672                   158.234
# ..                       ...                       ...
# 153                   13.023                     3.256
# 154                   15.120                       NaN
# 155                26494.397                   910.406
# 156                 4960.249                    67.450
# 157                 2557.908                   104.623
#
# [158 rows x 11 columns]

# %%
# check null values
df.isna().sum()
# Out:
# Country Code                0
# IncomeGroup                 0
# Country Name                0
# % Diabetes                  0
# pop2021                     0
# % pop > 65 years            4
# obesityRate                 0
# total_cases                 0
# total_deaths                4
# total_cases_per_million     0
# total_deaths_per_million    4
# dtype: int64

# %%
# drop Nan values from dataset
df.dropna(inplace=True)

# %%
# check summary of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 152 entries, 0 to 157
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Country Code              152 non-null    object
#  1   IncomeGroup               152 non-null    object
#  2   Country Name              152 non-null    object
#  3   % Diabetes                152 non-null    float64
#  4   pop2021                   152 non-null    float64
#  5   % pop > 65 years          152 non-null    float64
#  6   obesityRate               152 non-null    float64
#  7   total_cases               152 non-null    float64
#  8   total_deaths              152 non-null    float64
#  9   total_cases_per_million   152 non-null    float64
#  10  total_deaths_per_million  152 non-null    float64
# dtypes: float64(8), object(3)
# memory usage: 14.2+ KB

# %%
# get dataset total deaths more then 100
#df1 = df[df['total_deaths_per_million']>100]

# %%
#Group the data to see the features for each variable by Income Group
df.groupby(["IncomeGroup"]).mean()
# Out:
#                      % Diabetes       pop2021  % pop > 65 years  obesityRate  \
# IncomeGroup
# High income            8.148980  23206.738633         15.586920    23.669388
# Low income             5.426087  23094.690696          2.946712     8.030435
# Lower middle income    7.010526  74592.615132          5.298321    13.339474
# Upper middle income    9.109524  63376.708690          8.804383    21.978571
#
#                       total_cases  total_deaths  total_cases_per_million  \
# IncomeGroup
# High income          1.442796e+06  28840.346939             55275.869571
# Low income           2.974796e+04    619.652174              1136.439870
# Lower middle income  6.299453e+05   8993.947368              8465.799184
# Upper middle income  9.297726e+05  25124.714286             36284.253452
#
#                      total_deaths_per_million
# IncomeGroup
# High income                        888.084245
# Low income                          22.810565
# Lower middle income                191.401263
# Upper middle income                712.003143

# %%
gdp_df = df.copy()

# %%
gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 152 entries, 0 to 157
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Country Code              152 non-null    object
#  1   IncomeGroup               152 non-null    object
#  2   Country Name              152 non-null    object
#  3   % Diabetes                152 non-null    float64
#  4   pop2021                   152 non-null    float64
#  5   % pop > 65 years          152 non-null    float64
#  6   obesityRate               152 non-null    float64
#  7   total_cases               152 non-null    float64
#  8   total_deaths              152 non-null    float64
#  9   total_cases_per_million   152 non-null    float64
#  10  total_deaths_per_million  152 non-null    float64
# dtypes: float64(8), object(3)
# memory usage: 14.2+ KB

# %% [markdown]
# # Total COVID-19 Cases and Deaths

# %% [markdown]
# ## Top 25 Countries

# %%
df_cases = gdp_df.copy()
cases = df_cases.sort_values(by=['total_cases'], ascending = False)
cases_top25 = cases.head(25)

# %%
cases_top25
# Out:
#     Country Code          IncomeGroup    Country Name  % Diabetes  \
# 150          USA          High income   United States        10.8
# 67           IND  Lower middle income           India        10.4
# 22           BRA  Upper middle income          Brazil        10.4
# 50           FRA          High income          France         4.8
# 145          TUR  Upper middle income          Turkey        11.1
# 52           GBR          High income  United Kingdom         3.9
# 72           ITA          High income           Italy         5.0
# 45           ESP          High income           Spain         6.9
# 37           DEU          High income         Germany        10.4
# 5            ARG  Upper middle income       Argentina         5.9
# 118          POL          High income          Poland         6.1
# 32           COL  Upper middle income        Colombia         7.4
# 92           MEX  Upper middle income          Mexico        13.5
# 148          UKR  Lower middle income         Ukraine         6.1
# 115          PER  Upper middle income            Peru         6.6
# 66           IDN  Upper middle income       Indonesia         6.3
# 155          ZAF  Upper middle income    South Africa        12.7
# 108          NLD          High income     Netherlands         5.4
# 27           CAN          High income          Canada         7.6
# 29           CHL          High income           Chile         8.6
# 122          ROU          High income         Romania         6.9
# 69           IRQ  Upper middle income            Iraq         8.8
# 116          PHL  Lower middle income     Philippines         7.1
# 12           BEL          High income         Belgium         4.6
# 137          SWE          High income          Sweden         4.8
#
#          pop2021  % pop > 65 years  obesityRate  total_cases  total_deaths  \
# 150   332915.073         16.209606         36.2   31929351.0      570345.0
# 67   1393409.038          6.377924          3.9   16263695.0      186920.0
# 22    213993.437          9.251608         22.1   14167973.0      383502.0
# 50     65426.179         20.391370         21.6    5469674.0      102323.0
# 145    85042.738          8.726284         32.1    4501382.0       37329.0
# 52     68207.116         18.508696         27.8    4413834.0      127597.0
# 72     60367.477         23.012137         19.9    3920945.0      118357.0
# 45     46745.216         19.647823         23.8    3456886.0       77496.0
# 37     83900.473         21.562992         22.3    3254609.0       81203.0
# 5      45605.826         11.243108         28.3    2796768.0       60620.0
# 118    37797.005         18.116897         23.1    2731256.0       64168.0
# 32     51265.844          8.765830         22.3    2720619.0       70026.0
# 92    130262.216          7.416661         28.9    2319596.0      214079.0
# 148    43466.819         16.704990         24.1    2043901.0       43041.0
# 115    33359.418          8.393479         19.7    1734606.0       58604.0
# 66    276361.783          6.050303          6.9    1626812.0       44172.0
# 155    60041.994          5.415256         28.3    1571348.0       53995.0
# 108    17173.099         19.605320         20.4    1460753.0       17226.0
# 27     38067.903         17.647897         29.4    1164108.0       23810.0
# 29     19212.361         11.881540         28.0    1148320.0       25532.0
# 122    19127.774         18.790066         22.5    1039998.0       26943.0
# 69     41179.350          3.398533         30.4    1010304.0       15128.0
# 116   111046.913          5.314996          6.4     971049.0       16370.0
# 12     11632.326         19.006566         22.1     964526.0       23909.0
# 137    10160.169         20.198570         20.6     932076.0       13882.0
#
#      total_cases_per_million  total_deaths_per_million
# 150                96462.525                  1723.083
# 67                 11785.249                   135.449
# 22                 66654.179                  1804.211
# 50                 80262.064                  1501.489
# 145                53372.442                   442.606
# 52                 65018.321                  1879.577
# 72                 64849.925                  1957.549
# 45                 73936.521                  1657.499
# 37                 38845.258                   969.195
# 5                  61881.180                  1341.276
# 118                72166.473                  1695.476
# 32                 53468.255                  1376.219
# 92                 17990.743                  1660.393
# 148                46735.086                   984.160
# 115                52608.701                  1777.395
# 66                  5947.611                   161.492
# 155                26494.397                   910.406
# 108                85250.296                  1005.318
# 27                 30843.706                   630.860
# 29                 60070.488                  1335.620
# 122                54060.463                  1400.533
# 69                 25117.880                   376.108
# 116                 8861.465                   149.387
# 12                 83223.292                  2062.967
# 137                92291.423                  1374.555

# %%
#Here you can see an overview of the total COVID-19 cases and deaths (sorted by total cases) of the top 25 countries

plt.rcParams['figure.figsize'] = [8,8]
fig = plt.figure(figsize=(17,12))
ax1 = fig.add_subplot(221)


sns.barplot(cases_top25["Country Name"],cases_top25["total_cases"])

ax1.set_xticklabels(ax1.get_xticklabels(), rotation = 45, 
                   horizontalalignment='right',
                  fontweight='light',
                  fontsize='12')
ax1.set_xlabel("Country Name", size= 16)
ax1.set_ylabel("Total Cases", size= 16)
ax1.set_title("Top 25 Countries", size= 18)

ax2 = fig.add_subplot(222)
sns.barplot(cases_top25["Country Name"],cases_top25["total_deaths"])
ax2.set_xticklabels(ax2.get_xticklabels(), rotation = 45, 
                   horizontalalignment='right',
                  fontweight='light',
                  fontsize='12')

ax2 = fig.add_subplot(222)
ax2.set_xlabel("Country Name", size= 16)
ax2.set_ylabel("Total Deaths", size= 16)
ax2.set_title("Top 25 Countries", size= 18)

fig.tight_layout()
plt.show()

# %% [markdown]
#  ## Bottom 25 Countries

# %%
df_cases = gdp_df.copy()
cases = df_cases.sort_values(by=['total_cases'], ascending = False)
cases_low25 = cases.tail(25)

# %%
cases_low25
# Out:
#     Country Code          IncomeGroup              Country Name  % Diabetes  \
# 78           KHM  Lower middle income                  Cambodia         6.4
# 13           BEN  Lower middle income                     Benin         1.0
# 57           GNQ  Upper middle income         Equatorial Guinea         6.0
# 107          NIC  Lower middle income                 Nicaragua        11.4
# 70           ISL          High income                   Iceland         5.8
# 26           CAF           Low income  Central African Republic         6.0
# 138          SYC          High income                Seychelles        12.3
# 105          NER           Low income                     Niger         2.4
# 139          TCD           Low income                      Chad         6.0
# 129          SLE           Low income              Sierra Leone         2.4
# 33           COM  Lower middle income                   Comoros        12.3
# 23           BRB          High income                  Barbados        13.4
# 11           BDI           Low income                   Burundi         5.1
# 56           GNB           Low income             Guinea-Bissau         2.4
# 152          VNM  Lower middle income                   Vietnam         6.0
# 111          NZL          High income               New Zealand         6.2
# 134          STP  Lower middle income     Sao Tome and Principe         2.4
# 81           LBR           Low income                   Liberia         2.4
# 7            ATG          High income       Antigua and Barbuda        13.1
# 101          MUS          High income                 Mauritius        22.0
# 24           BTN  Lower middle income                    Bhutan        10.3
# 146          TZA  Lower middle income                  Tanzania         5.7
# 59           GRD  Upper middle income                   Grenada        10.7
# 49           FJI  Upper middle income                      Fiji        14.7
# 153          VUT  Lower middle income                   Vanuatu        11.9
#
#        pop2021  % pop > 65 years  obesityRate  total_cases  total_deaths  \
# 78   16946.438          4.717769          3.9       8193.0          59.0
# 13   12451.040          3.264885          9.6       7720.0          97.0
# 57    1449.896          2.424509          8.0       7505.0         106.0
# 107   6702.385          5.457992         23.7       6835.0         181.0
# 70     343.353         15.192121         21.9       6379.0          29.0
# 26    4919.981          2.814790          7.5       6175.0          85.0
# 138     98.908          7.805482         14.0       5170.0          26.0
# 105  25130.817          2.596711          5.5       5143.0         191.0
# 139  16914.985          2.491642          6.1       4735.0         169.0
# 129   8141.343          2.947737          8.7       4044.0          79.0
# 33     888.451          3.055403          7.8       3824.0         146.0
# 23     287.711         16.230990         23.1       3806.0          44.0
# 11   12255.433          2.312095          5.4       3732.0           6.0
# 56    2015.494          2.863260          9.5       3721.0          66.0
# 152  98168.833          7.553673          2.1       2824.0          35.0
# 111   4860.643         15.993956         30.8       2600.0          26.0
# 134    223.368          2.960159         12.4       2292.0          35.0
# 81    5180.203          3.285694          9.9       2091.0          85.0
# 7       98.731          9.054964         18.9       1217.0          31.0
# 101   1273.433         11.998727         10.8       1205.0          16.0
# 24     779.898          6.092974          6.4        992.0           1.0
# 146  61498.437          2.620541          8.4        509.0          21.0
# 59     113.021          9.677419         21.3        159.0           1.0
# 49     902.906          5.624230         30.2         86.0           2.0
# 153    314.464          3.616089         25.2          4.0           1.0
#
#      total_cases_per_million  total_deaths_per_million
# 78                   490.042                     3.529
# 13                   636.796                     8.001
# 57                  5349.309                    75.553
# 107                 1031.768                    27.323
# 70                 18693.040                    84.982
# 26                  1278.530                    17.599
# 138                52572.707                   264.389
# 105                  212.462                     7.890
# 139                  288.265                    10.289
# 129                  506.958                     9.903
# 33                  4397.449                   167.894
# 23                 13244.203                   153.112
# 11                   313.857                     0.505
# 56                  1890.754                    33.537
# 152                   29.012                     0.360
# 111                  539.169                     5.392
# 134                10458.065                   159.700
# 81                   413.431                    16.806
# 7                  12427.498                   316.559
# 101                  947.501                    12.581
# 24                  1285.620                     1.296
# 146                    8.521                     0.352
# 59                  1413.095                     8.887
# 49                    95.935                     2.231
# 153                   13.023                     3.256

# %%
#Here you can see an overview of the total COVID-19 cases and deaths (sorted by total cases) of the bottom 25 countries

plt.rcParams['figure.figsize'] = [8,8]
fig = plt.figure(figsize=(17,12))
ax1 = fig.add_subplot(221)


sns.barplot(cases_low25["Country Name"],cases_low25["total_cases"])

ax1.set_xticklabels(ax1.get_xticklabels(), rotation = 45, 
                   horizontalalignment='right',
                  fontweight='light',
                  fontsize='12')
ax1.set_xlabel("Country Name", size= 16)
ax1.set_ylabel("Total Cases", size= 16)
ax1.set_title("Bottom 25 Countries", size= 18)



ax2 = fig.add_subplot(222)
sns.barplot(cases_low25["Country Name"],cases_low25["total_deaths"])
ax2.set_xticklabels(ax2.get_xticklabels(), rotation = 45, 
                   horizontalalignment='right',
                  fontweight='light',
                  fontsize='12')
ax2.set_xlabel("Country Name", size= 16)
ax2.set_ylabel("Total Deaths", size= 16)
ax2.set_title("Bottom 25 Countries", size= 18)

fig.tight_layout()
plt.show()

# %% [markdown]
# # Cases and Death per Million

# %% [markdown]
# ## Top 25 Countries

# %%
df_cases = gdp_df.copy()
cases = df_cases.sort_values(by=['total_cases_per_million'], ascending = False)
cases_per_million_top25 = cases.head(25)

# %%
cases_per_million_top25
# Out:
#     Country Code          IncomeGroup   Country Name  % Diabetes     pop2021  \
# 97           MNE  Upper middle income     Montenegro         9.0     628.053
# 136          SVN          High income       Slovenia         5.9    2078.724
# 86           LUX          High income     Luxembourg         5.0     634.814
# 132          SRB  Upper middle income         Serbia         9.0    8697.550
# 17           BHR          High income        Bahrain        15.6    1748.296
# 71           ISR          High income         Israel         9.7    8789.774
# 150          USA          High income  United States        10.8  332915.073
# 137          SWE          High income         Sweden         4.8   10160.169
# 46           EST          High income        Estonia         4.2    1325.185
# 85           LTU          High income      Lithuania         3.8    2689.862
# 108          NLD          High income    Netherlands         5.4   17173.099
# 114          PAN          High income         Panama         7.7    4381.579
# 12           BEL          High income        Belgium         4.6   11632.326
# 119          PRT          High income       Portugal         9.8   10167.925
# 50           FRA          High income         France         4.8   65426.179
# 65           HUN          High income        Hungary         6.9    9634.164
# 63           HRV          High income        Croatia         5.4    4081.651
# 80           LBN  Upper middle income        Lebanon        11.2    6769.146
# 53           GEO  Upper middle income        Georgia         5.8    3979.765
# 28           CHE          High income    Switzerland         5.7    8715.494
# 45           ESP          High income          Spain         6.9   46745.216
# 118          POL          High income         Poland         6.1   37797.005
# 6            ARM  Upper middle income        Armenia         6.1    2968.127
# 121          QAT          High income          Qatar        15.6    2930.528
# 74           JOR  Upper middle income         Jordan        12.7   10269.021
#
#      % pop > 65 years  obesityRate  total_cases  total_deaths  \
# 97          15.389172         23.3      96187.0        1451.0
# 136         20.186284         20.2     234811.0        4187.0
# 86          14.274949         22.6      65813.0         790.0
# 132         18.740503         21.5     673520.0        6130.0
# 17           2.518810         29.8     168201.0         614.0
# 71          12.208674         26.1     837807.0        6346.0
# 150         16.209606         36.2   31929351.0      570345.0
# 137         20.198570         20.6     932076.0       13882.0
# 46          19.991808         21.2     119218.0        1120.0
# 85          20.158413         26.3     237950.0        3818.0
# 108         19.605320         20.4    1460753.0       17226.0
# 114          8.313837         22.7     361992.0        6198.0
# 12          19.006566         22.1     964526.0       23909.0
# 119         22.356691         20.8     832891.0       16956.0
# 50          20.391370         21.6    5469674.0      102323.0
# 65          19.694458         26.4     760967.0       26001.0
# 63          20.860135         24.4     316308.0        6738.0
# 80           7.273292         33.7     516600.0        7057.0
# 53          15.061056         21.7     300264.0        3981.0
# 28          18.837996         19.5     644396.0       10555.0
# 45          19.647823         23.8    3456886.0       77496.0
# 118         18.116897         23.1    2731256.0       64168.0
# 6           11.483668         20.2     211399.0        3969.0
# 121          1.523163         35.1     199980.0         407.0
# 74           3.893416         35.5     697487.0        8474.0
#
#      total_cases_per_million  total_deaths_per_million
# 97                153148.893                  2310.281
# 136               112947.898                  2014.015
# 86                105136.619                  1262.029
# 132                98980.160                   900.862
# 17                 98849.718                   360.840
# 71                 96794.296                   733.172
# 150                96462.525                  1723.083
# 137                92291.423                  1374.555
# 46                 89871.463                   844.302
# 85                 87407.996                  1402.495
# 108                85250.296                  1005.318
# 114                83896.052                  1436.462
# 12                 83223.292                  2062.967
# 119                81682.351                  1662.890
# 50                 80262.064                  1501.489
# 65                 78772.198                  2691.517
# 63                 77049.294                  1641.306
# 80                 75687.406                  1033.926
# 53                 75269.699                   997.951
# 28                 74456.897                  1219.580
# 45                 73936.521                  1657.499
# 118                72166.473                  1695.476
# 6                  71340.637                  1339.415
# 121                69411.953                   141.267
# 74                 68360.034                   830.529

# %%
#Here you can see an overview of the total COVID-19 cases and deaths per million (sorted by total cases) of the top 25 countries

plt.rcParams['figure.figsize'] = [8,8]
fig = plt.figure(figsize=(17,12))
ax1 = fig.add_subplot(221)


sns.barplot(cases_per_million_top25["Country Name"],cases_per_million_top25["total_cases_per_million"])

ax1.set_xticklabels(ax1.get_xticklabels(), rotation = 45, 
                   horizontalalignment='right',
                  fontweight='light',
                  fontsize='12')
ax1.set_xlabel("Country Name", size= 16)
ax1.set_ylabel("Total Cases per Million", size= 16)
ax1.set_title("Top 25 Countries", size= 18)



ax2 = fig.add_subplot(222)
sns.barplot(cases_per_million_top25["Country Name"],cases_per_million_top25["total_deaths_per_million"])
ax2.set_xticklabels(ax2.get_xticklabels(), rotation = 45, 
                   horizontalalignment='right',
                  fontweight='light',
                  fontsize='12')
ax2.set_xlabel("Country Name", size= 16)
ax2.set_ylabel("Total Deaths per Million", size= 16)
ax2.set_title("Top 25 Countries", size= 18)

fig.tight_layout()
plt.show()

# %%
#Top 25 Countries Grouped by Income
pie = cases_per_million_top25[["IncomeGroup", "total_deaths_per_million"]]
pie["IncomeGroup"].value_counts().plot(kind = "pie")

# %%
cases = cases_per_million_top25.groupby(["Country Name","IncomeGroup"])["total_cases_per_million",
                                            "total_deaths_per_million"].mean()

cm = sns.light_palette("green", as_cmap=True)
cases.style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
#     #T_360a85e2_b02d_11eb_a1f5_acde48001122row0_col0 {
#             background-color:  #defbde;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row0_col1 {
#             background-color:  #7ac37a;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row1_col0 {
#             background-color:  #93d193;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row1_col1 {
#             background-color:  #d2f4d2;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row2_col0 {
#             background-color:  #bee9be;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row2_col1 {
#             background-color:  #399f39;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row3_col0 {
#             background-color:  #cef2ce;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row3_col1 {
#             background-color:  #5eb45e;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row4_col0 {
#             background-color:  #acdfac;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row4_col1 {
#             background-color:  #a6dca6;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row5_col0 {
#             background-color:  #c6eec6;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row5_col1 {
#             background-color:  #6bbb6b;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row6_col0 {
#             background-color:  #d3f5d3;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row6_col1 {
#             background-color:  #99d599;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row7_col0 {
#             background-color:  #caf0ca;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row7_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row8_col0 {
#             background-color:  #99d599;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row8_col1 {
#             background-color:  #b0e2b0;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row9_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row9_col1 {
#             background-color:  #a7dda7;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row10_col0 {
#             background-color:  #d2f4d2;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row10_col1 {
#             background-color:  #95d395;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row11_col0 {
#             background-color:  #b2e3b2;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row11_col1 {
#             background-color:  #74c074;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row12_col0 {
#             background-color:  #82c882;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row12_col1 {
#             background-color:  #81c781;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row13_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row13_col1 {
#             background-color:  #229322;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row14_col0 {
#             background-color:  #b8e6b8;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row14_col1 {
#             background-color:  #98d498;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row15_col0 {
#             background-color:  #bce8bc;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row15_col1 {
#             background-color:  #70be70;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row16_col0 {
#             background-color:  #dcfadc;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row16_col1 {
#             background-color:  #59b159;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row17_col0 {
#             background-color:  #c2ebc2;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row17_col1 {
#             background-color:  #5db35d;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row18_col0 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row18_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row19_col0 {
#             background-color:  #93d193;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row19_col1 {
#             background-color:  #a1d9a1;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row20_col0 {
#             background-color:  #6dbc6d;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row20_col1 {
#             background-color:  #3da23d;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row21_col0 {
#             background-color:  #d7f7d7;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row21_col1 {
#             background-color:  #5db35d;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row22_col0 {
#             background-color:  #a5dba5;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row22_col1 {
#             background-color:  #77c277;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row23_col0 {
#             background-color:  #d5f6d5;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row23_col1 {
#             background-color:  #84c984;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row24_col0 {
#             background-color:  #9ad59a;
#             color:  #000000;
#         }    #T_360a85e2_b02d_11eb_a1f5_acde48001122row24_col1 {
#             background-color:  #57b057;
#             color:  #000000;
#         }</style><table id="T_360a85e2_b02d_11eb_a1f5_acde48001122" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_cases_per_million</th>        <th class="col_heading level0 col1" >total_deaths_per_million</th>    </tr>    <tr>        <th class="index_name level0" >Country Name</th>        <th class="index_name level1" >IncomeGroup</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_360a85e2_b02d_11eb_a1f5_acde48001122level0_row0" class="row_heading level0 row0" >Armenia</th>
#                         <th id="T_360a85e2_b02d_11eb_a1f5_acde48001122level1_row0" class="row_heading level1 row0" >Upper middle income</th>
#                         <td id="T_360a85e2_b02d_11eb_a1f5_acde48001122row0_col0" class="data row0 col0" >71340.637000</td>
#                         <td id="T_360a85e2_b02d_11eb_a1f5_acde48001122row0_col1" class="data row0 col1" >1339.415000</td>
#             </tr>
#             <tr>
#                         <th id="T_360a85e2_b02d_11eb_a1f5_acde48001122level0_row1" class="row_heading level0 row1" >Bahrain</th>
#                         <th id="T_360a85e2_b02d_11eb_a1f5_acde48001122level1_row1" c

# %% [markdown]
# ## Bottom 25 Countries

# %%
df_cases = gdp_df.copy()
cases = df_cases.sort_values(by=['total_cases_per_million'], ascending = False)
cases_per_million_bottom25 = cases.tail(25)

# %%
cases_per_million_bottom25
# Out:
#     Country Code          IncomeGroup  Country Name  % Diabetes      pop2021  \
# 64           HTI           Low income         Haiti         6.7    11541.685
# 107          NIC  Lower middle income     Nicaragua        11.4     6702.385
# 101          MUS          High income     Mauritius        22.0     1273.433
# 133          SSD           Low income   South Sudan        10.2    11381.378
# 147          UGA           Low income        Uganda         2.5    47123.531
# 131          SOM           Low income       Somalia         5.1    16359.504
# 106          NGA  Lower middle income       Nigeria         3.1   211400.708
# 125          SDN           Low income         Sudan        22.1    44909.353
# 1            AGO  Lower middle income        Angola         4.5    33933.610
# 141          THA  Upper middle income      Thailand         7.0    69950.850
# 94           MLI           Low income          Mali         2.4    20855.735
# 13           BEN  Lower middle income         Benin         1.0    12451.040
# 14           BFA           Low income  Burkina Faso         7.3    21497.096
# 111          NZL          High income   New Zealand         6.2     4860.643
# 129          SLE           Low income  Sierra Leone         2.4     8141.343
# 78           KHM  Lower middle income      Cambodia         6.4    16946.438
# 81           LBR           Low income       Liberia         2.4     5180.203
# 11           BDI           Low income       Burundi         5.1    12255.433
# 139          TCD           Low income          Chad         6.0    16914.985
# 105          NER           Low income         Niger         2.4    25130.817
# 49           FJI  Upper middle income          Fiji        14.7      902.906
# 30           CHN  Upper middle income         China         9.2  1444216.107
# 152          VNM  Lower middle income       Vietnam         6.0    98168.833
# 153          VUT  Lower middle income       Vanuatu        11.9      314.464
# 146          TZA  Lower middle income      Tanzania         5.7    61498.437
#
#      % pop > 65 years  obesityRate  total_cases  total_deaths  \
# 64           5.063670         22.7      12944.0         251.0
# 107          5.457992         23.7       6835.0         181.0
# 101         11.998727         10.8       1205.0          16.0
# 133          3.376805          8.6      10504.0         114.0
# 147          1.962550          5.3      41529.0         341.0
# 131          2.889204          8.3      13459.0         689.0
# 106          2.743083          8.9     164588.0        2061.0
# 125          3.627317          8.6      33599.0        2300.0
# 1            2.199342          8.2      25051.0         572.0
# 141         12.406250         10.0      48113.0         117.0
# 94           2.495128          8.6      13420.0         456.0
# 13           3.264885          9.6       7720.0          97.0
# 14           2.407288          5.6      13212.0         156.0
# 111         15.993956         30.8       2600.0          26.0
# 129          2.947737          8.7       4044.0          79.0
# 78           4.717769          3.9       8193.0          59.0
# 81           3.285694          9.9       2091.0          85.0
# 11           2.312095          5.4       3732.0           6.0
# 139          2.491642          6.1       4735.0         169.0
# 105          2.596711          5.5       5143.0         191.0
# 49           5.624230         30.2         86.0           2.0
# 30          11.472193          6.2     102332.0        4844.0
# 152          7.553673          2.1       2824.0          35.0
# 153          3.616089         25.2          4.0           1.0
# 146          2.620541          8.4        509.0          21.0
#
#      total_cases_per_million  total_deaths_per_million
# 64                  1135.186                    22.013
# 107                 1031.768                    27.323
# 101                  947.501                    12.581
# 133                  938.383                    10.184
# 147                  907.916                     7.455
# 131                  846.839                    43.352
# 106                  798.430                     9.998
# 125                  766.239                    52.452
# 1                    762.210                    17.404
# 141                  689.298                     1.676
# 94                   662.689                    22.518
# 13                   636.796                     8.001
# 14                   632.054                     7.463
# 111                  539.169                     5.392
# 129                  506.958                     9.903
# 78                   490.042                     3.529
# 81                   413.431                    16.806
# 11                   313.857                     0.505
# 139                  288.265                    10.289
# 105                  212.462                     7.890
# 49                    95.935                     2.231
# 30                    71.097                     3.365
# 152                   29.012                     0.360
# 153                   13.023                     3.256
# 146                    8.521                     0.352

# %%
#Here you can see an overview of the total COVID-19 cases and deaths per million (sorted by total cases) of the top 25 countries

plt.rcParams['figure.figsize'] = [8,8]
fig = plt.figure(figsize=(17,12))
ax1 = fig.add_subplot(221)


sns.barplot(cases_per_million_bottom25["Country Name"],cases_per_million_bottom25["total_cases_per_million"])

ax1.set_xticklabels(ax1.get_xticklabels(), rotation = 45, 
                   horizontalalignment='right',
                  fontweight='light',
                  fontsize='12')
ax1.set_xlabel("Country Name", size= 16)
ax1.set_ylabel("Total Cases per Million", size= 16)
ax1.set_title("Bottom 25 Countries", size= 18)



ax2 = fig.add_subplot(222)
sns.barplot(cases_per_million_bottom25["Country Name"],cases_per_million_bottom25["total_deaths_per_million"])
ax2.set_xticklabels(ax2.get_xticklabels(), rotation = 45, 
                   horizontalalignment='right',
                  fontweight='light',
                  fontsize='12')
ax2.set_xlabel("Country Name", size= 16)
ax2.set_ylabel("Total Deaths per Million", size= 16)
ax2.set_title("Bottom 25 Countries", size= 18)

fig.tight_layout()
plt.show()

# %%
#Bottom 25 Countries Grouped by Income
pie = cases_per_million_bottom25[["IncomeGroup", "total_deaths_per_million"]]
pie["IncomeGroup"].value_counts().plot(kind = "pie")

# %%
# groupby country name and get mean of features

cases = cases_per_million_bottom25.groupby(["Country Name","IncomeGroup"])["total_cases_per_million",
                                            "total_deaths_per_million"].mean()
cm = sns.light_palette("green", as_cmap=True)
cases.style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
#     #T_36742236_b02d_11eb_a1f5_acde48001122row0_col0 {
#             background-color:  #4caa4c;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row0_col1 {
#             background-color:  #9bd69b;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row1_col0 {
#             background-color:  #66b866;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row1_col1 {
#             background-color:  #c4edc4;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row2_col0 {
#             background-color:  #67b967;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row2_col1 {
#             background-color:  #c7eec7;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row3_col0 {
#             background-color:  #a7dda7;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row3_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row4_col0 {
#             background-color:  #83c983;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row4_col1 {
#             background-color:  #d8f8d8;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row5_col0 {
#             background-color:  #ade0ad;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row5_col1 {
#             background-color:  #bae7ba;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row6_col0 {
#             background-color:  #d9f8d9;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row6_col1 {
#             background-color:  #d9f8d9;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row7_col0 {
#             background-color:  #d4f6d4;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row7_col1 {
#             background-color:  #ddfbdd;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row8_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row8_col1 {
#             background-color:  #86ca86;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row9_col0 {
#             background-color:  #93d193;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row9_col1 {
#             background-color:  #9ed79e;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row10_col0 {
#             background-color:  #60b560;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row10_col1 {
#             background-color:  #84c984;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row11_col0 {
#             background-color:  #269526;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row11_col1 {
#             background-color:  #b0e1b0;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row12_col0 {
#             background-color:  #7ac37a;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row12_col1 {
#             background-color:  #d0f3d0;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row13_col0 {
#             background-color:  #158b15;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row13_col1 {
#             background-color:  #6fbd6f;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row14_col0 {
#             background-color:  #bce8bc;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row14_col1 {
#             background-color:  #c4edc4;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row15_col0 {
#             background-color:  #44a644;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row15_col1 {
#             background-color:  #bbe8bb;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row16_col0 {
#             background-color:  #80c780;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row16_col1 {
#             background-color:  #bce8bc;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row17_col0 {
#             background-color:  #3aa03a;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row17_col1 {
#             background-color:  #289628;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row18_col0 {
#             background-color:  #289628;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row18_col1 {
#             background-color:  #bae7ba;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row19_col0 {
#             background-color:  #4ba94b;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row19_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row20_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row20_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row21_col0 {
#             background-color:  #5bb25b;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row21_col1 {
#             background-color:  #e0fce0;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row22_col0 {
#             background-color:  #2e992e;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row22_col1 {
#             background-color:  #c7eec7;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row23_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row23_col1 {
#             background-color:  #d9f8d9;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row24_col0 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_36742236_b02d_11eb_a1f5_acde48001122row24_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }</style><table id="T_36742236_b02d_11eb_a1f5_acde48001122" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_cases_per_million</th>        <th class="col_heading level0 col1" >total_deaths_per_million</th>    </tr>    <tr>        <th class="index_name level0" >Country Name</th>        <th class="index_name level1" >IncomeGroup</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_36742236_b02d_11eb_a1f5_acde48001122level0_row0" class="row_heading level0 row0" >Angola</th>
#                         <th id="T_36742236_b02d_11eb_a1f5_acde48001122level1_row0" class="row_heading level1 row0" >Lower middle income</th>
#                         <td id="T_36742236_b02d_11eb_a1f5_acde48001122row0_col0" class="data row0 col0" >762.210000</td>
#                         <td id="T_36742236_b02d_11eb_a1f5_acde48001122row0_col1" class="data row0 col1" >17.404000</td>
#             </tr>
#             <tr>
#                         <th id="T_36742236_b02d_11eb_a1f5_acde48001122level0_row1" class="row_heading level0 row1" >Benin</th>
#                         <th id="T_36742236_b02d_11eb_a1f5_acde48001122level1_row1" class="r

# %% [markdown]
# # Correlation of COVID-19 with Age and Comorbidities

# %%
# Compute the correlation matrix
corr= df.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
fig, ax = plt.subplots(figsize = (16,12))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap =True)
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask = mask, cmap =cmap,annot=True, vmax =.3, center =0,
            square =True, linewidths = .5, cbar_kws= {"shrink": .5})
#plt.savefig("Heatmap.png", transparent = False,facecolor= "white", dpi = 100, bbox_inches = "tight")

# %% [markdown]
# # COVID-19 Deaths, Age and Comorbidities Regression Plots

# %%
#sns.regplot(x="% pop > 65 years", y="total_deaths_per_million", data=gdp_df);

from scipy import stats as sp

g = sns.lmplot(x="% pop > 65 years", y="total_deaths_per_million", data=gdp_df,
               aspect=1)

def annotate(data, **kws):
    r, p = sp.stats.pearsonr(gdp_df["% pop > 65 years"], gdp_df['total_deaths_per_million'])
    ax = plt.gca()
    ax.text(.05, .9,'r={:.2f}, p={:.2g}'.format(r, p),
            transform=ax.transAxes)
    
g.map_dataframe(annotate)
plt.xlabel("% pop > 65 years", size =16)
plt.ylabel("total_deaths_per_million", size =16)
plt.title("Relationship of COVID-19 Deaths and Age")
plt.show()

# %%
def regression(col): 
    
    plt.rcParams['figure.figsize'] = [8,8]
    fig = plt.figure(figsize=(17,12))
    
    ax1 = fig.add_subplot(331)

    ax1 = fig.add_subplot(331)
    sns.regplot(gdp_df[col], gdp_df["total_deaths_per_million"], scatter_kws={"color": "purple"}, line_kws={"color": "red"})
    ax1.set_xlabel(col)
    ax1.set_ylabel("total_deaths_per_million")

    
    

    #fig.colorbar(h)
    fig.tight_layout()
    plt.show()
columns = ['% Diabetes','% pop > 65 years','obesityRate', 'total_cases', 
           'total_deaths','total_cases_per_million']
for col in columns:
    regression(col)
